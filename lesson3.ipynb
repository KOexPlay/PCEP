# %%
age = int(input("Enter age: "))

if age >= 18:
    print("Adult")
else:
    print("Minor")
# Out:
# Minor

# %%
age = int(input("Enter age: "))
print("Adult" if age >= 18 else "Minor")
# Out:
# Adult

# %%
print(int == type(7))
# Out:
# True
