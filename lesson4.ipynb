# %%
'''Create a program with a for loop and a break statement. 
The program should iterate over characters in an email address, exit the loop when it reaches the @ symbol, 
and print the part before @ on one line.
'''

# %%
emailAddress = "jimHopkins@dundermifflin.com"
tempStr = ""

# %%
for i in emailAddress:
    if i == "@":
        break
    tempStr += i
print(tempStr)
# Out:
# jimHopkins

# %%
'''2.Write a program that takes a word as an input and
prints it out after removing vowels from it'''
# Out:
# '2.Write a program that takes a word as an input and\nprints it out after removing vowels from it'

# %%
word = input("Input word: ")
tempStr = ""
vowls = ["a", "e", "o", "i", "u"]
for l in word:
    if l in vowls:
        continue
    print(l,end = "")
# Out:
# wds

# %%
x = ['ab', 'cd'] 

for i in x:   

      i.upper()

print(x)
# Out:
# ['ab', 'cd']

# %%
True = False
# Out:
#   Cell In[5], line 1
#     True = False
#     ^
# SyntaxError: cannot assign to True
