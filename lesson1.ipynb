# %%
var1 = 35
var2 = hex(var1)
var2
# Out:
# '0x23'

# %%
var3 = "0x23"
var4 = int(var3, )
var4
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 2
#       1 var3 = "0x23"
# ----> 2 var4 = int(var3, )
#       3 var4
#
# ValueError: invalid literal for int() with base 10: '0x23'

# %%
var5 = "1010"
var6 = int(var5, 2)
var6
# Out:
# 10

# %%
var7 = 10
var8 = oct(var7)
var8
# Out:
# '0o12'

# %%
var3 = 16
var4 = bin(var3)
var4
# Out:
# '0b10000'

# %%
print("Hello\nperson")
# Out:
# Hello
# person

# %%
print("Hello\tperson")
print("backslash\\")
#print(":\Users\kaige\python projects\")
print('He said \'she\'s coming\'')
print('He said "she\'s coming"')
# Out:
# Hello	person
# backslash\
# He said 'she's coming'
# He said "she's coming"
