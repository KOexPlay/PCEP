# %%
list = [0, 4]
var1 = list
print(var1)

var1[1] = "four"
print(var1)
print(list)

print(id(var1))
print(id(list))
# Out:
# [0, 4]
# [0, 'four']
# [0, 'four']
# 2903930879424
# 2903930879424

# %%
list = [0, 4]
var1 = [0, 4]
print(var1)

var1[1] = "four"
print(var1)
print(list)

print(id(var1))
print(id(list))
# Out:
# [0, 4]
# [0, 'four']
# [0, 4]
# 2903930985728
# 2903930982976

# %%
list1 = []
for i in range(1, 11):
    if i%2 == 0:
        list1.append(i**2)
print(list1)
# Out:
# [4, 16, 36, 64, 100]

# %%
list1 = [i**2 for i in range(1, 11) if i**2%2==0]
print(list1)
# Out:
# [4, 16, 36, 64, 100]

# %%
tuple1 = (1,)
print(type(tuple1))
# Out:
# <class 'tuple'>
