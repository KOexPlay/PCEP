# %% [markdown]
# ## Binary Operations ##

# %%
1/2*4
# Out:
# 2.0

# %%
2**2**3
# Out:
# 256

# %% [markdown]
# ## Bitwise combinations ##

# %%
a = 10
b = 12

print(a & b)
print(a | (b-8))
print(~(a+1))
# Out:
# 8
# 14
# -12

# %%
x = 5
n = 2
print(x << n)
# Out:
# 20

# %%
print("a", "b", "x", end = ". ")
print("text", "that is", "written", sep = ", ")
# Out:
# a b x. text, that is, written
